# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 744

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

city_data= []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_weather = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date, "Current Weather": city_current_weather})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fairmont
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | marsh harbour
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | hami
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | bograd
# Processing Record 11 of Set 1 | tynda
# Processing Record 12 of Set 1 | cabedelo
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | san andres
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | bulungu
# Processing Record 18 of Set 1 | ancud
# Processing Record 19 of Set 1 | pietarsaari
# Processing Record 20 of Set 1 | daund
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | nur
# Processing Record 23 of Set 1 | sinnamary
# Processing Record 24 of Set 1 | udachnyy
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | marystown
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | mount isa
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | talnakh
# Processing Record 35 of Set 1 | vestmannaeyjar
# Processing Record 36 of Set 1 | puerto salgar
# Processing Record 37 of Set 1 | santo antonio do ica
# Processing Record 38 of Set 1 | bubaque
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | ta khmau
# Processing Record 43 of Set 1 | comodoro rivadavia
# Processing Record 44 of Set 1 | east london
# Processing Record 45 of Set 1 | galeana
# Processing Record 46 of Set 1 | tessalit
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | souillac
# Processing Record 50 of Set 1 | sechura
# Processing Record 1 of Set 2 | santa catalina
# Processing Record 2 of Set 2 | jiaojiang
# Processing Record 3 of Set 2 | hamilton
# Processing Record 4 of Set 2 | kavieng
# Processing Record 5 of Set 2 | komsomolskiy
# Processing Record 6 of Set 2 | aguimes
# Processing Record 7 of Set 2 | kurilsk
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | itarema
# Processing Record 12 of Set 2 | batu
# Processing Record 13 of Set 2 | tsumeb
# Processing Record 14 of Set 2 | bluff
# Processing Record 15 of Set 2 | pangnirtung
# Processing Record 16 of Set 2 | quang ngai
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | grindavik
# Processing Record 19 of Set 2 | havoysund
# Processing Record 20 of Set 2 | bengkulu
# Processing Record 21 of Set 2 | olafsvik
# Processing Record 22 of Set 2 | fairbanks
# Processing Record 23 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | bereda
# Processing Record 28 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 2 | ketchikan
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | karratha
# Processing Record 33 of Set 2 | sabya
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | mahebourg
# Processing Record 36 of Set 2 | ust-tsilma
# Processing Record 37 of Set 2 | jamestown
# Processing Record 38 of Set 2 | mehamn
# Processing Record 39 of Set 2 | cape town
# Processing Record 40 of Set 2 | kalomo
# City not found. Skipping...
# Processing Record 41 of Set 2 | isangel
# Processing Record 42 of Set 2 | jimo
# Processing Record 43 of Set 2 | chapais
# Processing Record 44 of Set 2 | pangody
# Processing Record 45 of Set 2 | kirakira
# Processing Record 46 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | revere
# Processing Record 49 of Set 2 | bambous virieux
# Processing Record 50 of Set 2 | namatanai
# Processing Record 1 of Set 3 | batsfjord
# Processing Record 2 of Set 3 | katobu
# Processing Record 3 of Set 3 | katsuura
# Processing Record 4 of Set 3 | bathsheba
# Processing Record 5 of Set 3 | igarka
# Processing Record 6 of Set 3 | pevek
# Processing Record 7 of Set 3 | verkhoyansk
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | port hardy
# Processing Record 10 of Set 3 | santa cruz
# Processing Record 11 of Set 3 | high level
# Processing Record 12 of Set 3 | kahului
# Processing Record 13 of Set 3 | leningradskiy
# Processing Record 14 of Set 3 | anadyr
# Processing Record 15 of Set 3 | mokshan
# Processing Record 16 of Set 3 | athlone
# Processing Record 17 of Set 3 | duobao
# Processing Record 18 of Set 3 | loreto
# Processing Record 19 of Set 3 | kutum
# Processing Record 20 of Set 3 | carnarvon
# Processing Record 21 of Set 3 | pauini
# Processing Record 22 of Set 3 | wattegama
# Processing Record 23 of Set 3 | victoria
# Processing Record 24 of Set 3 | abhar
# Processing Record 25 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 3 | yongzhou
# Processing Record 27 of Set 3 | ilhabela
# Processing Record 28 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 29 of Set 3 | barranca
# Processing Record 30 of Set 3 | chokurdakh
# Processing Record 31 of Set 3 | turbana
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | baruun-urt
# Processing Record 34 of Set 3 | willowmore
# Processing Record 35 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | tautira
# Processing Record 39 of Set 3 | antofagasta
# Processing Record 40 of Set 3 | bolshaya dzhalga
# Processing Record 41 of Set 3 | provideniya
# Processing Record 42 of Set 3 | vila velha
# Processing Record 43 of Set 3 | smidovich
# Processing Record 44 of Set 3 | krasnoborsk
# Processing Record 45 of Set 3 | nakhon thai
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | suratgarh
# Processing Record 48 of Set 3 | khatanga
# Processing Record 49 of Set 3 | padang
# Processing Record 50 of Set 3 | norman wells
# Processing Record 1 of Set 4 | vanimo
# Processing Record 2 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 4 | taonan
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | saint-gilles
# Processing Record 6 of Set 4 | encheng
# Processing Record 7 of Set 4 | mount gambier
# Processing Record 8 of Set 4 | riyadh
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | ostrovnoy
# Processing Record 11 of Set 4 | oranjestad
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | benjamin constant
# Processing Record 14 of Set 4 | saint-joseph
# Processing Record 15 of Set 4 | longyearbyen
# Processing Record 16 of Set 4 | saint-philippe
# Processing Record 17 of Set 4 | laguna
# Processing Record 18 of Set 4 | isabela
# Processing Record 19 of Set 4 | soyo
# Processing Record 20 of Set 4 | gat
# Processing Record 21 of Set 4 | hermanus
# Processing Record 22 of Set 4 | puerto baquerizo moreno
# Processing Record 23 of Set 4 | doctor arroyo
# Processing Record 24 of Set 4 | esmeraldas
# Processing Record 25 of Set 4 | kodiak
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | mbaiki
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | amuntai
# Processing Record 30 of Set 4 | cherskiy
# Processing Record 31 of Set 4 | azle
# Processing Record 32 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 4 | sungairaya
# Processing Record 34 of Set 4 | poya
# Processing Record 35 of Set 4 | nikolskoye
# Processing Record 36 of Set 4 | tuy hoa
# Processing Record 37 of Set 4 | los llanos de aridane
# Processing Record 38 of Set 4 | kununurra
# Processing Record 39 of Set 4 | vila franca do campo
# Processing Record 40 of Set 4 | cocobeach
# Processing Record 41 of Set 4 | vila
# Processing Record 42 of Set 4 | mitsamiouli
# Processing Record 43 of Set 4 | bam
# Processing Record 44 of Set 4 | keti bandar
# Processing Record 45 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 4 | okato
# Processing Record 47 of Set 4 | castro
# Processing Record 48 of Set 4 | constitucion
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | touros
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | namibe
# Processing Record 5 of Set 5 | ulaanbaatar
# Processing Record 6 of Set 5 | adrar
# Processing Record 7 of Set 5 | ishim
# Processing Record 8 of Set 5 | port augusta
# Processing Record 9 of Set 5 | honningsvag
# Processing Record 10 of Set 5 | hay river
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | kangaatsiaq
# Processing Record 13 of Set 5 | zlitan
# Processing Record 14 of Set 5 | filingue
# Processing Record 15 of Set 5 | zhicheng
# Processing Record 16 of Set 5 | yulara
# Processing Record 17 of Set 5 | natal
# Processing Record 18 of Set 5 | jinka
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | tazovskiy
# Processing Record 23 of Set 5 | tugolesskiy bor
# Processing Record 24 of Set 5 | garowe
# Processing Record 25 of Set 5 | iqaluit
# Processing Record 26 of Set 5 | faanui
# Processing Record 27 of Set 5 | chernihiv
# Processing Record 28 of Set 5 | warrington
# Processing Record 29 of Set 5 | shelburne
# Processing Record 30 of Set 5 | tromso
# Processing Record 31 of Set 5 | kalmunai
# Processing Record 32 of Set 5 | kushima
# Processing Record 33 of Set 5 | sorong
# Processing Record 34 of Set 5 | puerto asis
# Processing Record 35 of Set 5 | chancay
# Processing Record 36 of Set 5 | osa
# Processing Record 37 of Set 5 | whitehorse
# Processing Record 38 of Set 5 | marawi
# Processing Record 39 of Set 5 | roebourne
# Processing Record 40 of Set 5 | buchanan
# Processing Record 41 of Set 5 | nome
# Processing Record 42 of Set 5 | bandarbeyla
# Processing Record 43 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 5 | qibili
# City not found. Skipping...
# Processing Record 46 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 5 | adeje
# Processing Record 48 of Set 5 | maningrida
# Processing Record 49 of Set 5 | mbanza-ngungu
# Processing Record 50 of Set 5 | wilhelmshaven
# Processing Record 1 of Set 6 | nhulunbuy
# Processing Record 2 of Set 6 | potosi
# Processing Record 3 of Set 6 | suba
# Processing Record 4 of Set 6 | yar-sale
# Processing Record 5 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 6 of Set 6 | mogadishu
# Processing Record 7 of Set 6 | olden
# Processing Record 8 of Set 6 | zdvinsk
# Processing Record 9 of Set 6 | gorontalo
# Processing Record 10 of Set 6 | bereslavka
# Processing Record 11 of Set 6 | kassala
# Processing Record 12 of Set 6 | tagusao
# Processing Record 13 of Set 6 | buala
# Processing Record 14 of Set 6 | riihimaki
# Processing Record 15 of Set 6 | margate
# Processing Record 16 of Set 6 | srikakulam
# Processing Record 17 of Set 6 | shaoguan
# Processing Record 18 of Set 6 | vilhena
# Processing Record 19 of Set 6 | san ignacio
# Processing Record 20 of Set 6 | lieksa
# Processing Record 21 of Set 6 | indiaroba
# Processing Record 22 of Set 6 | puerto ayora
# Processing Record 23 of Set 6 | daoukro
# Processing Record 24 of Set 6 | ambilobe
# Processing Record 25 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 26 of Set 6 | finschhafen
# Processing Record 27 of Set 6 | saint anthony
# Processing Record 28 of Set 6 | manono
# Processing Record 29 of Set 6 | bukama
# Processing Record 30 of Set 6 | ribeira grande
# Processing Record 31 of Set 6 | grand forks
# Processing Record 32 of Set 6 | cartagena
# Processing Record 33 of Set 6 | nanortalik
# Processing Record 34 of Set 6 | korla
# Processing Record 35 of Set 6 | kuloy
# Processing Record 36 of Set 6 | ngerengere
# Processing Record 37 of Set 6 | sao filipe
# Processing Record 38 of Set 6 | monrovia
# Processing Record 39 of Set 6 | kaura namoda
# Processing Record 40 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 6 | novyy urengoy
# Processing Record 42 of Set 6 | ivnya
# Processing Record 43 of Set 6 | arraial do cabo
# Processing Record 44 of Set 6 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 6 | hualmay
# Processing Record 46 of Set 6 | hauge
# Processing Record 47 of Set 6 | agadez
# Processing Record 48 of Set 6 | petrovskiy
# Processing Record 49 of Set 6 | dingle
# Processing Record 50 of Set 6 | mackay
# Processing Record 1 of Set 7 | pontiac
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | laizhou
# Processing Record 4 of Set 7 | lompoc
# Processing Record 5 of Set 7 | oktyabrskoye
# Processing Record 6 of Set 7 | half moon bay
# Processing Record 7 of Set 7 | bilibino
# Processing Record 8 of Set 7 | vardo
# Processing Record 9 of Set 7 | ishigaki
# Processing Record 10 of Set 7 | wanaka
# Processing Record 11 of Set 7 | valdepenas
# Processing Record 12 of Set 7 | kargasok
# Processing Record 13 of Set 7 | sao joao da barra
# Processing Record 14 of Set 7 | nyurba
# Processing Record 15 of Set 7 | tilichiki
# Processing Record 16 of Set 7 | taltal
# Processing Record 17 of Set 7 | muros
# Processing Record 18 of Set 7 | severo-kurilsk
# Processing Record 19 of Set 7 | cabo san lucas
# Processing Record 20 of Set 7 | evensk
# Processing Record 21 of Set 7 | la plata
# Processing Record 22 of Set 7 | wagar
# Processing Record 23 of Set 7 | kidal
# Processing Record 24 of Set 7 | santa catarina de tepehuanes
# Processing Record 25 of Set 7 | tamiahua
# Processing Record 26 of Set 7 | nizwa
# Processing Record 27 of Set 7 | languyan
# Processing Record 28 of Set 7 | cidreira
# Processing Record 29 of Set 7 | navirai
# Processing Record 30 of Set 7 | kuusamo
# Processing Record 31 of Set 7 | santa maria
# Processing Record 32 of Set 7 | beni suef
# Processing Record 33 of Set 7 | dvinskoy
# Processing Record 34 of Set 7 | haines junction
# Processing Record 35 of Set 7 | werneck
# Processing Record 36 of Set 7 | alofi
# Processing Record 37 of Set 7 | saryg-sep
# Processing Record 38 of Set 7 | daan
# Processing Record 39 of Set 7 | inhambane
# Processing Record 40 of Set 7 | nampula
# Processing Record 41 of Set 7 | boa vista
# Processing Record 42 of Set 7 | qaqortoq
# Processing Record 43 of Set 7 | along
# Processing Record 44 of Set 7 | sulangan
# Processing Record 45 of Set 7 | mezen
# Processing Record 46 of Set 7 | cootamundra
# Processing Record 47 of Set 7 | kharan
# Processing Record 48 of Set 7 | lagoa
# Processing Record 49 of Set 7 | serebryanyy bor
# Processing Record 50 of Set 7 | sidi bin nur
# Processing Record 1 of Set 8 | sinjar
# Processing Record 2 of Set 8 | hokitika
# Processing Record 3 of Set 8 | badhni kalan
# Processing Record 4 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 8 | san quintin
# Processing Record 6 of Set 8 | torbay
# Processing Record 7 of Set 8 | micheweni
# Processing Record 8 of Set 8 | swellendam
# Processing Record 9 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 8 | sitka
# Processing Record 11 of Set 8 | wajir
# Processing Record 12 of Set 8 | grand gaube
# Processing Record 13 of Set 8 | tiksi
# Processing Record 14 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 8 | plettenberg bay
# Processing Record 16 of Set 8 | bulaevo
# Processing Record 17 of Set 8 | fort myers beach
# Processing Record 18 of Set 8 | san patricio
# Processing Record 19 of Set 8 | urumqi
# Processing Record 20 of Set 8 | arman
# Processing Record 21 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 22 of Set 8 | kavaratti
# Processing Record 23 of Set 8 | ust-karsk
# Processing Record 24 of Set 8 | mayor pablo lagerenza
# Processing Record 25 of Set 8 | abu samrah
# Processing Record 26 of Set 8 | shagonar
# Processing Record 27 of Set 8 | khovu-aksy
# Processing Record 28 of Set 8 | jumla
# Processing Record 29 of Set 8 | geraldton
# Processing Record 30 of Set 8 | palora
# Processing Record 31 of Set 8 | salumbar
# Processing Record 32 of Set 8 | ossora
# Processing Record 33 of Set 8 | teguldet
# Processing Record 34 of Set 8 | solnechnyy
# Processing Record 35 of Set 8 | poli
# Processing Record 36 of Set 8 | volchikha
# Processing Record 37 of Set 8 | bonavista
# Processing Record 38 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 8 | coquimbo
# Processing Record 40 of Set 8 | kichmengskiy gorodok
# Processing Record 41 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 8 | nadym
# Processing Record 43 of Set 8 | aswan
# Processing Record 44 of Set 8 | ushtobe
# Processing Record 45 of Set 8 | poum
# Processing Record 46 of Set 8 | toowoomba
# Processing Record 47 of Set 8 | opunake
# Processing Record 48 of Set 8 | ekibastuz
# Processing Record 49 of Set 8 | manta
# Processing Record 50 of Set 8 | puerto del rosario
# Processing Record 1 of Set 9 | brownsville
# Processing Record 2 of Set 9 | galle
# Processing Record 3 of Set 9 | baoning
# Processing Record 4 of Set 9 | goure
# Processing Record 5 of Set 9 | kuandian
# Processing Record 6 of Set 9 | srandakan
# Processing Record 7 of Set 9 | almaznyy
# Processing Record 8 of Set 9 | samarai
# Processing Record 9 of Set 9 | chany
# Processing Record 10 of Set 9 | bojnurd
# Processing Record 11 of Set 9 | ryotsu
# Processing Record 12 of Set 9 | zhezkazgan
# Processing Record 13 of Set 9 | dalby
# Processing Record 14 of Set 9 | mandali
# Processing Record 15 of Set 9 | yatou
# Processing Record 16 of Set 9 | nago
# Processing Record 17 of Set 9 | belyy yar
# Processing Record 18 of Set 9 | upata
# Processing Record 19 of Set 9 | kruisfontein
# Processing Record 20 of Set 9 | khani
# Processing Record 21 of Set 9 | cockburn town
# Processing Record 22 of Set 9 | muroto
# Processing Record 23 of Set 9 | lianran
# Processing Record 24 of Set 9 | akyab
# Processing Record 25 of Set 9 | airai
# Processing Record 26 of Set 9 | hazorasp
# Processing Record 27 of Set 9 | praya
# Processing Record 28 of Set 9 | sambava
# Processing Record 29 of Set 9 | coahuayana
# Processing Record 30 of Set 9 | esperance
# Processing Record 31 of Set 9 | albury
# Processing Record 32 of Set 9 | port hedland
# Processing Record 33 of Set 9 | kundiawa
# Processing Record 34 of Set 9 | tarko-sale
# Processing Record 35 of Set 9 | lormi
# Processing Record 36 of Set 9 | emerald
# Processing Record 37 of Set 9 | caravelas
# Processing Record 38 of Set 9 | kawalu
# Processing Record 39 of Set 9 | luderitz
# Processing Record 40 of Set 9 | breves
# Processing Record 41 of Set 9 | huarmey
# Processing Record 42 of Set 9 | lev tolstoy
# Processing Record 43 of Set 9 | greeneville
# Processing Record 44 of Set 9 | south bend
# Processing Record 45 of Set 9 | omurtag
# Processing Record 46 of Set 9 | melito di porto salvo
# Processing Record 47 of Set 9 | meulaboh
# Processing Record 48 of Set 9 | bonthe
# Processing Record 49 of Set 9 | avera
# Processing Record 50 of Set 9 | colesberg
# Processing Record 1 of Set 10 | moron
# Processing Record 2 of Set 10 | salalah
# Processing Record 3 of Set 10 | tooele
# Processing Record 4 of Set 10 | port lincoln
# Processing Record 5 of Set 10 | vostok
# Processing Record 6 of Set 10 | pechenga
# Processing Record 7 of Set 10 | petushki
# Processing Record 8 of Set 10 | oistins
# Processing Record 9 of Set 10 | auki
# Processing Record 10 of Set 10 | malpe
# Processing Record 11 of Set 10 | rock sound
# Processing Record 12 of Set 10 | beecher
# Processing Record 13 of Set 10 | tatsinskaya
# City not found. Skipping...
# Processing Record 14 of Set 10 | ulaangom
# Processing Record 15 of Set 10 | mastic beach
# Processing Record 16 of Set 10 | zaragoza
# Processing Record 17 of Set 10 | kizukuri
# Processing Record 18 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 19 of Set 10 | prince george
# Processing Record 20 of Set 10 | roald
# Processing Record 21 of Set 10 | thinadhoo
# Processing Record 22 of Set 10 | manaure
# Processing Record 23 of Set 10 | bilma
# Processing Record 24 of Set 10 | oranzherei
# Processing Record 25 of Set 10 | kupang
# Processing Record 26 of Set 10 | nara
# Processing Record 27 of Set 10 | saint andrews
# Processing Record 28 of Set 10 | manokwari
# Processing Record 29 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 10 | jelenia gora
# Processing Record 31 of Set 10 | shirdi
# Processing Record 32 of Set 10 | nata
# Processing Record 33 of Set 10 | broome
# Processing Record 34 of Set 10 | mgandu
# Processing Record 35 of Set 10 | aksu
# Processing Record 36 of Set 10 | moose factory
# Processing Record 37 of Set 10 | mahbubabad
# Processing Record 38 of Set 10 | tateyama
# Processing Record 39 of Set 10 | ilulissat
# Processing Record 40 of Set 10 | sironj
# Processing Record 41 of Set 10 | havelock
# Processing Record 42 of Set 10 | wicklow
# Processing Record 43 of Set 10 | richards bay
# Processing Record 44 of Set 10 | pont-a-mousson
# Processing Record 45 of Set 10 | kaiserslautern
# Processing Record 46 of Set 10 | ascension
# Processing Record 47 of Set 10 | thayetmyo
# Processing Record 48 of Set 10 | lorengau
# Processing Record 49 of Set 10 | kaeo
# Processing Record 50 of Set 10 | zaoyang
# Processing Record 1 of Set 11 | aranos
# Processing Record 2 of Set 11 | jacareacanga
# Processing Record 3 of Set 11 | sao felix do xingu
# Processing Record 4 of Set 11 | naryan-mar
# Processing Record 5 of Set 11 | sioux lookout
# Processing Record 6 of Set 11 | khilok
# Processing Record 7 of Set 11 | koumac
# Processing Record 8 of Set 11 | sharjah
# Processing Record 9 of Set 11 | san buenaventura
# Processing Record 10 of Set 11 | lakatoro
# Processing Record 11 of Set 11 | canakkale
# Processing Record 12 of Set 11 | san jeronimo
# Processing Record 13 of Set 11 | gunjur
# Processing Record 14 of Set 11 | tamworth
# Processing Record 15 of Set 11 | moindou
# Processing Record 16 of Set 11 | hasaki
# Processing Record 17 of Set 11 | hue
# Processing Record 18 of Set 11 | narsaq
# Processing Record 19 of Set 11 | seoul
# Processing Record 20 of Set 11 | hovd
# Processing Record 21 of Set 11 | loikaw
# Processing Record 22 of Set 11 | skogn
# Processing Record 23 of Set 11 | el balyana
# City not found. Skipping...
# Processing Record 24 of Set 11 | asau
# Processing Record 25 of Set 11 | umm lajj
# Processing Record 26 of Set 11 | kisangani
# Processing Record 27 of Set 11 | sucua
# Processing Record 28 of Set 11 | wasilla
# Processing Record 29 of Set 11 | safaga
# Processing Record 30 of Set 11 | sur
# Processing Record 31 of Set 11 | lerwick
# Processing Record 32 of Set 11 | guerrero negro
# Processing Record 33 of Set 11 | wageningen
# Processing Record 34 of Set 11 | ambovombe
# Processing Record 35 of Set 11 | imbituba
# Processing Record 36 of Set 11 | douglas
# Processing Record 37 of Set 11 | sueyoshi
# Processing Record 38 of Set 11 | coihaique
# Processing Record 39 of Set 11 | sorland
# Processing Record 40 of Set 11 | kenora
# Processing Record 41 of Set 11 | jaciara
# Processing Record 42 of Set 11 | balakhta
# Processing Record 43 of Set 11 | sabla
# Processing Record 44 of Set 11 | ndiekro
# City not found. Skipping...
# Processing Record 45 of Set 11 | ergani
# Processing Record 46 of Set 11 | loukhi
# Processing Record 47 of Set 11 | rocha
# Processing Record 48 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 11 | miandoab
# Processing Record 50 of Set 11 | panguipulli
# Processing Record 1 of Set 12 | gazanjyk
# Processing Record 2 of Set 12 | oyama
# Processing Record 3 of Set 12 | saint-augustin
# Processing Record 4 of Set 12 | oxford
# Processing Record 5 of Set 12 | nautla
# Processing Record 6 of Set 12 | grand-santi
# Processing Record 7 of Set 12 | agirish
# Processing Record 8 of Set 12 | quchan
# Processing Record 9 of Set 12 | aldama
# Processing Record 10 of Set 12 | berlevag
# Processing Record 11 of Set 12 | ueda
# Processing Record 12 of Set 12 | narrabri
# Processing Record 13 of Set 12 | gazojak
# Processing Record 14 of Set 12 | sagarejo
# Processing Record 15 of Set 12 | arlit
# Processing Record 16 of Set 12 | atbasar
# Processing Record 17 of Set 12 | ikom
# Processing Record 18 of Set 12 | miyang
# Processing Record 19 of Set 12 | husavik
# Processing Record 20 of Set 12 | north bend
# Processing Record 21 of Set 12 | progreso
# Processing Record 22 of Set 12 | ouadda
# Processing Record 23 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 24 of Set 12 | labrea
# Processing Record 25 of Set 12 | tuatapere
# Processing Record 26 of Set 12 | palmer
# Processing Record 27 of Set 12 | tsiroanomandidy
# Processing Record 28 of Set 12 | del gallego
# Processing Record 29 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 30 of Set 12 | anar darreh
# City not found. Skipping...
# Processing Record 31 of Set 12 | catumbela
# Processing Record 32 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 33 of Set 12 | kyshtovka
# Processing Record 34 of Set 12 | morros
# Processing Record 35 of Set 12 | aleppo
# Processing Record 36 of Set 12 | gigmoto
# Processing Record 37 of Set 12 | seydi
# Processing Record 38 of Set 12 | ulcinj
# Processing Record 39 of Set 12 | evora
# Processing Record 40 of Set 12 | parvatsar
# Processing Record 41 of Set 12 | ponta delgada
# Processing Record 42 of Set 12 | pisco
# Processing Record 43 of Set 12 | gazli
# Processing Record 44 of Set 12 | shitanjing
# Processing Record 45 of Set 12 | alta floresta
# Processing Record 46 of Set 12 | marhaura
# Processing Record 47 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 48 of Set 12 | ocos
# Processing Record 49 of Set 12 | la ronge
# Processing Record 50 of Set 12 | antalaha
# Processing Record 1 of Set 13 | fare
# Processing Record 2 of Set 13 | abalak
# Processing Record 3 of Set 13 | altamira
# Processing Record 4 of Set 13 | san cristobal
# Processing Record 5 of Set 13 | jega
# Processing Record 6 of Set 13 | panguna
# Processing Record 7 of Set 13 | ust-kuyga
# Processing Record 8 of Set 13 | derzhavinsk
# Processing Record 9 of Set 13 | vagur
# Processing Record 10 of Set 13 | ahipara
# Processing Record 11 of Set 13 | gasa
# Processing Record 12 of Set 13 | draguignan
# Processing Record 13 of Set 13 | yerofey pavlovich
# Processing Record 14 of Set 13 | kuryk
# Processing Record 15 of Set 13 | charleston
# Processing Record 16 of Set 13 | bilopillya
# Processing Record 17 of Set 13 | gombong
# Processing Record 18 of Set 13 | praia da vitoria
# Processing Record 19 of Set 13 | guayaramerin
# Processing Record 20 of Set 13 | molepolole
# Processing Record 21 of Set 13 | jalu
# Processing Record 22 of Set 13 | yamethin
# Processing Record 23 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 13 | leshukonskoye
# Processing Record 25 of Set 13 | columbia
# Processing Record 26 of Set 13 | mukono
# Processing Record 27 of Set 13 | surt
# Processing Record 28 of Set 13 | floresta
# Processing Record 29 of Set 13 | pacific grove
# Processing Record 30 of Set 13 | port blair
# Processing Record 31 of Set 13 | klodzko
# Processing Record 32 of Set 13 | taunggyi
# Processing Record 33 of Set 13 | fayaoue
# Processing Record 34 of Set 13 | brae
# Processing Record 35 of Set 13 | iquique
# Processing Record 36 of Set 13 | igrim
# Processing Record 37 of Set 13 | cam ranh
# Processing Record 38 of Set 13 | etaples
# Processing Record 39 of Set 13 | kargat
# Processing Record 40 of Set 13 | yondo
# Processing Record 41 of Set 13 | matadi
# Processing Record 42 of Set 13 | sao gabriel da cachoeira
# Processing Record 43 of Set 13 | road town
# Processing Record 44 of Set 13 | kargil
# Processing Record 45 of Set 13 | polyarnyy
# Processing Record 46 of Set 13 | shingu
# Processing Record 47 of Set 13 | peniche
# Processing Record 48 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 13 | meadow lake
# Processing Record 50 of Set 13 | glendive
# Processing Record 1 of Set 14 | harper
# Processing Record 2 of Set 14 | yerbogachen
# Processing Record 3 of Set 14 | wundanyi
# Processing Record 4 of Set 14 | misratah
# Processing Record 5 of Set 14 | rawson
# Processing Record 6 of Set 14 | honiara
# Processing Record 7 of Set 14 | fort nelson
# Processing Record 8 of Set 14 | san-pedro
# Processing Record 9 of Set 14 | amapa
# Processing Record 10 of Set 14 | namie
# Processing Record 11 of Set 14 | cajati
# Processing Record 12 of Set 14 | koslan
# Processing Record 13 of Set 14 | halifax
# Processing Record 14 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 15 of Set 14 | taseyevo
# Processing Record 16 of Set 14 | roma
# Processing Record 17 of Set 14 | san policarpo
# Processing Record 18 of Set 14 | aklavik
# Processing Record 19 of Set 14 | lavrentiya
# Processing Record 20 of Set 14 | puerto leguizamo
# Processing Record 21 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 22 of Set 14 | labe
# Processing Record 23 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 14 | codrington
# Processing Record 25 of Set 14 | mozarlandia
# Processing Record 26 of Set 14 | muisne
# Processing Record 27 of Set 14 | macapa
# Processing Record 28 of Set 14 | ampanihy
# Processing Record 29 of Set 14 | lashio
# Processing Record 30 of Set 14 | primo tapia
# Processing Record 31 of Set 14 | kollumerland
# City not found. Skipping...
# Processing Record 32 of Set 14 | cancun
# Processing Record 33 of Set 14 | deputatskiy
# Processing Record 34 of Set 14 | powder springs
# Processing Record 35 of Set 14 | mayskiy
# Processing Record 36 of Set 14 | tigzirt
# Processing Record 37 of Set 14 | tazmalt
# Processing Record 38 of Set 14 | inongo
# Processing Record 39 of Set 14 | great yarmouth
# Processing Record 40 of Set 14 | seddon
# Processing Record 41 of Set 14 | xining
# Processing Record 42 of Set 14 | tanda
# Processing Record 43 of Set 14 | xai-xai
# Processing Record 44 of Set 14 | morro bay
# Processing Record 45 of Set 14 | bisira
# Processing Record 46 of Set 14 | paamiut
# Processing Record 47 of Set 14 | key west
# Processing Record 48 of Set 14 | morondava
# Processing Record 49 of Set 14 | suoyarvi
# Processing Record 50 of Set 14 | terrace bay
# Processing Record 1 of Set 15 | itoman
# Processing Record 2 of Set 15 | talara
# Processing Record 3 of Set 15 | lata
# Processing Record 4 of Set 15 | susanville
# Processing Record 5 of Set 15 | yambio
# Processing Record 6 of Set 15 | solikamsk
# Processing Record 7 of Set 15 | timra
# Processing Record 8 of Set 15 | freeport
# Processing Record 9 of Set 15 | shamary
# Processing Record 10 of Set 15 | bang saphan
# Processing Record 11 of Set 15 | maralal
# Processing Record 12 of Set 15 | acarau
# Processing Record 13 of Set 15 | rafai
# Processing Record 14 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 15 | xiantao
# Processing Record 16 of Set 15 | stromness
# Processing Record 17 of Set 15 | neryungri
# Processing Record 18 of Set 15 | santa rosa
# Processing Record 19 of Set 15 | boali
# Processing Record 20 of Set 15 | ellisras
# Processing Record 21 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 15 | svetlaya
# Processing Record 24 of Set 15 | iracoubo
# Processing Record 25 of Set 15 | qandala
# Processing Record 26 of Set 15 | severnyy
# Processing Record 27 of Set 15 | praia
# Processing Record 28 of Set 15 | bowen
# Processing Record 29 of Set 15 | fort abbas
# Processing Record 30 of Set 15 | caucaia
# Processing Record 31 of Set 15 | pingliang
# Processing Record 32 of Set 15 | usinsk
# Processing Record 33 of Set 15 | kloulklubed
# Processing Record 34 of Set 15 | charters towers
# Processing Record 35 of Set 15 | savonlinna
# Processing Record 36 of Set 15 | sovetskiy
# Processing Record 37 of Set 15 | mineros
# Processing Record 38 of Set 15 | shakawe
# Processing Record 39 of Set 15 | lusambo
# Processing Record 40 of Set 15 | kushmurun
# Processing Record 41 of Set 15 | innisfail
# Processing Record 42 of Set 15 | kaoma
# Processing Record 43 of Set 15 | lasa
# Processing Record 44 of Set 15 | keetmanshoop
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Fairmont  39.49  -80.14     57.00        71           0        2.75
# 1         Albany  42.60  -73.97     48.99        93           1        2.06
# 2         Bethel  41.37  -73.41     50.00        87           1        2.37
# 3  Marsh Harbour  26.54  -77.06     78.17        85         100       28.32
# 4           Lebu -37.62  -73.65     51.69        92          41       19.04
# 5           Hami  42.80   93.45     51.19        35           0        4.90
# 6       Tasiilaq  65.61  -37.64     33.13        95         100       31.14
# 7          Kapaa  22.08 -159.32     80.60        69          75       13.87
# 8           Hilo  19.73 -155.09     78.80        78          90        9.17
# 9         Bograd  54.23   90.83     28.40        92         100        2.24
#
#   Country                 Date       Current Weather
# 0      US  2020-11-09 04:11:16             clear sky
# 1      US  2020-11-09 04:13:34             clear sky
# 2      US  2020-11-09 04:16:16             clear sky
# 3      BS  2020-11-09 04:16:16         moderate rain
# 4      CL  2020-11-09 04:16:17      scattered clouds
# 5      CN  2020-11-09 04:16:17             clear sky
# 6      GL  2020-11-09 04:16:17       overcast clouds
# 7      US  2020-11-09 04:16:18         broken clouds
# 8      US  2020-11-09 04:13:10  heavy intensity rain
# 9      RU  2020-11-09 04:16:18                  mist

# %%
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Weather']
city_data_df=city_data_df[new_column_order]

# %%
city_data_df.head()
# Out:
#             City Country                 Date    Lat    Lng  Max Temp  \
# 0       Fairmont      US  2020-11-09 04:11:16  39.49 -80.14     57.00
# 1         Albany      US  2020-11-09 04:13:34  42.60 -73.97     48.99
# 2         Bethel      US  2020-11-09 04:16:16  41.37 -73.41     50.00
# 3  Marsh Harbour      BS  2020-11-09 04:16:16  26.54 -77.06     78.17
# 4           Lebu      CL  2020-11-09 04:16:17 -37.62 -73.65     51.69
#
#    Humidity  Cloudiness  Wind Speed   Current Weather
# 0        71           0        2.75         clear sky
# 1        93           1        2.06         clear sky
# 2        87           1        2.37         clear sky
# 3        85         100       28.32     moderate rain
# 4        92          41       19.04  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-5f4cd66f0e37> in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label = "City ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
